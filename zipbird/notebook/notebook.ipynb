# %%
import pickle
import pyfolio as pf
from pyfolio import plotting

with open('results/s2_mrlong-95-01-01-to-23-12-31-.pickle', 'rb') as file:
    loaded = pickle.load(file)
    perf2 = loaded['perf']
    returns1, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf2)
    
pf.create_returns_tear_sheet(returns1, positions, transactions)
# Out:
# c:\Users\liu_w\AppData\Local\cache\zipline-reloaded\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.725%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1995-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>347</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>19.725%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>18302.751%</td>
#     </tr>
# ...

# %%
import pickle
import pyfolio as pf
from pyfolio import plotting

with open('results/s1_sp500-95-01-01-to-23-12-31-.pickle', 'rb') as file:
    loaded = pickle.load(file)
    perf2 = loaded['perf']
    returns2, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf2)
    
pf.create_returns_tear_sheet(returns2, positions, transactions)
# Out:
# c:\Users\liu_w\AppData\Local\cache\zipline-reloaded\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.693%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1995-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>347</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>17.693%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>11108.203%</td>
#     </tr>
# ...

# %%
import pickle
import pyfolio as pf
from pyfolio import plotting

with open('results/s3_mrshort-95-01-01-to-23-12-31-.pickle', 'rb') as file:
    loaded = pickle.load(file)
    perf2 = loaded['perf']
    returns3, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf2)
    
pf.create_returns_tear_sheet(returns3, positions, transactions)
# Out:
# c:\Users\liu_w\AppData\Local\cache\zipline-reloaded\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.725%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1995-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>347</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>19.725%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>18302.751%</td>
#     </tr>
# ...

# %%
import pickle
import pyfolio as pf
from pyfolio import plotting

with open('results/s21_longmom-95-01-01-to-23-12-31-.pickle', 'rb') as file:
    loaded = pickle.load(file)
    perf2 = loaded['perf']
    returns3, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf2)
    
pf.create_returns_tear_sheet(returns3, positions, transactions)
# Out:
# c:\Users\liu_w\AppData\Local\cache\zipline-reloaded\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.539%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1995-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>347</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.539%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>973.66%</td>
#     </tr>
# ...

# %%
from zipbird.notebook import performance_summary
performance_summary.monthly_map_and_holding(returns3)
# Out:
# <h1>Monthly Performance</h1>
#     <table class='table table-hover table-condensed table-striped'>
#     <thead>
#     <tr>
#     <th style="text-align:right">Year</th>
#     <th style="text-align:right">Jan</th>
#     <th style="text-align:right">Feb</th>
#     <th style="text-align:right">Mar</th>
#     <th style="text-align:right">Apr</th>
#     <th style="text-align:right">May</th>
#     <th style="text-align:right">Jun</th>
#     <th style="text-align:right">Jul</th>
#     <th style="text-align:right">Aug</th>
#     <th style="text-align:right">Sep</th>
#     <th style="text-align:right">Oct</th>
#     <th style="text-align:right">Nov</th>
#     <th style="text-align:right">Dec</th>
#     <th style="text-align:right">Year</th>
#     <th style="text-align:right">Benchmark</th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr><td align='right'><b>1995</b></td>
# <td align='right'>+2.2</td>
# <td align='right'>+4.1</td>
# <td align='right'>+2.9</td>
# <td align='right'>-3.2</td>
# ...

# %%
transactions
# Out:
#                                                    sid  \
# 1995-01-03 21:00:00+00:00    Equity(3178 [BSN-199801])
# 1995-01-03 21:00:00+00:00  Equity(15179 [NPIX-200108])
# 1995-01-04 21:00:00+00:00   Equity(21121 [TLC-199905])
# 1995-01-04 21:00:00+00:00          Equity(4117 [CGNX])
# 1995-01-05 21:00:00+00:00          Equity(2016 [AVNW])
# ...                                                ...
# 2023-11-02 20:00:00+00:00          Equity(5586 [CVNA])
# 2023-12-01 21:00:00+00:00          Equity(5243 [CRSP])
# 2023-12-04 21:00:00+00:00          Equity(5243 [CRSP])
# 2023-12-07 21:00:00+00:00          Equity(20550 [SYM])
# 2023-12-11 21:00:00+00:00          Equity(20550 [SYM])
#
#                                                 symbol   price  \
# 1995-01-03 21:00:00+00:00    Equity(3178 [BSN-199801])   13.80
# 1995-01-03 21:00:00+00:00  Equity(15179 [NPIX-200108])   26.16
# 1995-01-04 21:00:00+00:00   Equity(21121 [TLC-199905])   22.92
# ...
